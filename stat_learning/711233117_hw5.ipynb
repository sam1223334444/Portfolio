# %% [markdown]
# ### 兩群與三群生成資料函式

# %%
import numpy as np
from scipy.stats import multivariate_normal
from sklearn.model_selection import train_test_split

def GenDataforN(seed, n_list, mu_list, Cov_list):
    rng = np.random.default_rng(seed=seed)
    X_list, y_list = [], []

    for i, n in enumerate(n_list):
        mvn = rng.multivariate_normal(mean=mu_list[i], cov=Cov_list[i], size=n)
        X_list.append(mvn)
        y_list.append(np.full(n, i))

    X = np.vstack(X_list)
    y = np.hstack(y_list)
    return X, y


#切割訓練與測試資料
#X = D[:, 0:2]
#Y = D[:, 2]
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
#D_train = np.hstack((X_train, Y_train.reshape(-1, 1)))
#D_test = np.hstack((X_test, Y_test.reshape(-1, 1)))

# %% [markdown]
# ### 母體資料散佈

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.model_selection import train_test_split

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([2, 3])]
            , Cov_list = [np.array([[1, 0], [0, 1]])
                          ,np.array([[1, 0], [0, 1]])] )

X1,y1= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([1, 1])]
            , Cov_list = [np.array([[0.5, 0], [0, 0.5]])
                          ,np.array([[0.5, 0], [0, 0.5]])] )

################## 資料散佈 #########################
fig , ax = plt.subplots(nrows = 1 ,ncols = 2 ,figsize = (9.5,3.9))

ax[0].grid(True,linewidth = 0.4)
ax[0].set_xlabel('$X_1$') , ax[0].set_ylabel('$X_2$')
colors = ['blue' if i == 0 else 'red' for i in y]
ax[0].scatter(X[:, 0], X[:, 1], c = colors, s = 30, marker = 'o', alpha = 0.5)
ax[0].set_title(f'$(x_1,x_2)\sim BVN(\\vec\mu_1,\\vec\mu_2,\\Sigma_1,\\Sigma_2)$ , significant difference between $\\vec\mu$' ,fontsize = 8.5)

ax[1].grid(True,linewidth = 0.4)
ax[1].set_xlabel('$X_1$') , ax[1].set_ylabel('$X_2$')
colors = ['blue' if i == 0 else 'red' for i in y1]
ax[1].scatter(X1[:, 0], X1[:, 1], c = colors, s = 30, marker = 'o', alpha = 0.5)
ax[1].set_title(f'$(x_1,x_2)\sim BVN(\\vec\mu_1,\\vec\mu_2,\\Sigma_1,\\Sigma_2)$ , similar $\\vec\mu$' ,fontsize = 8.5)
plt.savefig('statcomp_hw5_plot1.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
################# 生成資料 #####################
X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([1, 0]) , np.array([1, 0])]
            , Cov_list = [np.array([[4, -5], [-5, 4]])
                          ,np.array([[4, 5], [5, 4]])] )

X1,y1= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([2, 0])]
            , Cov_list = [np.array([[1, 0.8], [0.8, 1]])
                          ,np.array([[1, 0.8], [0.8, 1]])] )


################## 資料散佈 #########################
fig , ax = plt.subplots(nrows = 1 ,ncols = 2 ,figsize = (9.5,3.9))

ax[0].grid(True,linewidth = 0.4)
ax[0].set_xlabel('$X_1$') , ax[0].set_ylabel('$X_2$')
colors = ['blue' if i == 0 else 'red' for i in y]
ax[0].scatter(X[:, 0], X[:, 1], c = colors, s = 30, marker = 'o', alpha = 0.5)
ax[0].set_title(f'$(x_1,x_2)\sim BVN(\\vec\mu_1,\\vec\mu_2,\\Sigma_1,\\Sigma_2)$ , different correlation' ,fontsize = 8.5)

ax[1].grid(True,linewidth = 0.4)
ax[1].set_xlabel('$X_1$') , ax[1].set_ylabel('$X_2$')
colors = ['blue' if i == 0 else 'red' for i in y]
ax[1].scatter(X1[:, 0], X1[:, 1], c = colors, s = 30, marker = 'o', alpha = 0.5)
ax[1].set_title(f'$(x_1,x_2)\sim BVN(\\vec\mu_1,\\vec\mu_2,\\Sigma_1,\\Sigma_2)$ , same correlation' ,fontsize = 8.5)
plt.savefig('statcomp_hw5_plot2.png')
# Out:
# C:\Users\yangs\AppData\Local\Temp\ipykernel_17736\795068418.py:10: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   mvn = rng.multivariate_normal(mean=mu_list[i], cov=Cov_list[i], size=n)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
################# 生成資料 #####################
X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([0, 0])]
            , Cov_list = [np.array([[1, 0], [0 , 1]])
                          ,np.array([[0.2, 0], [0, 0.2]])] )

X1,y1= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([0, 0])]
            , Cov_list = [np.array([[5, 0], [0, 5]])
                          ,np.array([[3, 0], [0, 3]])] )


################## 資料散佈 #########################
fig , ax = plt.subplots(nrows = 1 ,ncols = 2 ,figsize = (9.5,3.9))

ax[0].grid(True,linewidth = 0.4)
ax[0].set_xlabel('$X_1$') , ax[0].set_ylabel('$X_2$')
colors = ['blue' if i == 0 else 'red' for i in y]
ax[0].scatter(X[:, 0], X[:, 1], c = colors, s = 30, marker = 'o', alpha = 0.5)
ax[0].set_title(f'$(x_1,x_2)\sim BVN(\\vec\mu_1,\\vec\mu_2,\\Sigma_1,\\Sigma_2)$ , significant different in $\\Sigma$' ,fontsize = 8.5)

ax[1].grid(True,linewidth = 0.4)
ax[1].set_xlabel('$X_1$') , ax[1].set_ylabel('$X_2$')
colors = ['blue' if i == 0 else 'red' for i in y]
ax[1].scatter(X1[:, 0], X1[:, 1], c = colors, s = 30, marker = 'o', alpha = 0.5)
ax[1].set_title(f'$(x_1,x_2)\sim BVN(\\vec\mu_1,\\vec\mu_2,\\Sigma_1,\\Sigma_2)$ , similar $\\Sigma$' ,fontsize = 8.5)
plt.savefig('statcomp_hw5_plot3.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from sklearn.model_selection import train_test_split

X,y= GenDataforN(seed = 123 , n_list =[200,200,200]
            , mu_list = [np.array([0, 0]) , np.array([2, 3]) , np.array([-2, 3])]
            , Cov_list = [np.array([[1, 0], [0, 1]])
                          ,np.array([[1, 0], [0, 1]])
                          ,np.array([[1, 0], [0, 1]])
                          ] )

################## 資料散佈 #########################
ax = plt.gca()
ax.grid(True,linewidth = 0.4)
ax.set_xlabel('$X_1$') , ax.set_ylabel('$X_2$')
colors = ['blue' if i == 0 else 'red' if i==1 else 'orange' for i in y]
plot = ax.scatter(X[:, 0], X[:, 1], c = colors, s = 30, marker = 'o', alpha = 0.5)
plt.title(f'$(x_1,x_2,x_3)\sim BVN(\\vec\mu_1,\\vec\mu_2,\\vec\mu_3,\\Sigma_1,\\Sigma_2,\\Sigma_3)$ , three groups data' )
plt.savefig('statcomp_hw5_plot4.png')

# %% [markdown]
# ### 2群資料判別

# %% [markdown]
# 1.$\mu$差異大

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([2, 3])]
            , Cov_list = [np.array([[1, 0], [0, 1]])
                          ,np.array([[1, 0], [0, 1]])] )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
D_train = np.hstack((X_train, y_train.reshape(-1, 1)))
D_test = np.hstack((X_test, y_test.reshape(-1, 1)))

D = D_train
X = D[:, 0:2]
y = D[:,2]

fig,ax=plt.subplots(1,2,figsize=(14,6),squeeze=False)
fig.suptitle('Different Models to Classify training dataset for two groups',fontsize = 14)
group_colors = ['blue' if i == 0 else 'red' for i in y]
ax[0][0].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' ) 
ax[0][1].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' )

#draw LDA
Lda=LinearDiscriminantAnalysis()
Lda.fit(X,y)
trainErrLDA=1-Lda.score(X,y)
x_min,x_max=plt.xlim()
y_min,y_max=plt.ylim()
x_=np.linspace(x_min,x_max,len(D[:, 0:1]))
y_=np.linspace(y_min,y_max,len(D[:, 1:2]))
xx,yy=np.meshgrid(x_,y_)
Z0=Lda.predict_proba(np.c_[xx.ravel(),yy.ravel()])#算出後驗機率
Z0=Z0[:,1].reshape(xx.shape)

# contoursLDA=ax[0][0].contour(xx,yy,Z0,[0.5],colors='g')
# contoursLDA1=ax[0][1].contour(xx,yy,Z0,[0.5],colors='g')
C1, C2 = X[y==0,:], X[y==1,:]
n = D[:,0].size
n1, n2 = C1[:,0].size, C2[:,0].size
pi1, pi2 = n1/n, n2/n
mu1, mu2 = np.mean(C1, axis = 0), np.mean(C2, axis = 0)
Sigma = (np.cov(C1.T) + np.cov(C2.T))/2
#draw classification line of LDA
K = np.log(pi1/pi2) - 0.5 * (mu1 + mu2)  @ LA.inv(Sigma) @ (mu1 - mu2).T
L = LA.inv(Sigma) @ (mu1 - mu2).T
f = lambda x : -L[0]/L[1] * x - K/L[1]
x = np.linspace(x_min,x_max, 10)
b=ax[0][0].plot(x, f(x) ,c = 'green' ,linestyle =':')
b=ax[0][1].plot(x, f(x) ,c = 'green' ,linestyle =':')

#draw QDA
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Qda.fit(X, y)
trainErrQDA=1-Qda.score(X,y)
Z2 = Qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z2 = Z2[:, 1].reshape(xx.shape)
contoursQDA= ax[0][0].contour(xx, yy, Z2, [0.5],colors = 'green' )
contoursQDA1= ax[0][1].contour(xx, yy, Z2, [0.5],colors = 'green' )

#draw KNN
K = [15,30]
Knn = neighbors.KNeighborsClassifier(K[0], weights = 'uniform')
Knn1 = neighbors.KNeighborsClassifier(K[1], weights = 'uniform')
Knn.fit(X, y)
Knn1.fit(X, y)
trainingErrKNN = 1 - Knn.score(X, y) 
trainingErrKNN1 = 1 - Knn1.score(X, y)

z1 = Knn.predict(np.c_[xx.ravel(), yy.ravel()])
z10 = Knn1.predict(np.c_[xx.ravel(), yy.ravel()])
Z1 = z1.reshape(xx.shape)
Z10 = z10.reshape(xx.shape)
cmap_light =colors.ListedColormap(['purple', 'pink'])
contoursKNN=ax[0][0].contourf(xx, yy, Z1, cmap = cmap_light, alpha = 0.3)
contoursKNN1=ax[0][1].contourf(xx, yy, Z10, cmap = cmap_light, alpha = 0.3)

# h1,_=contoursLDA.legend_elements()
# h11,_=contoursLDA1.legend_elements()
h2,_=contoursQDA.legend_elements()
h3,_=contoursKNN.legend_elements()
h33,_=contoursKNN1.legend_elements()

ax[0][0].legend([b[0],h2[0],h3[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=15) Missclassifaction is {:.3f}'.format(trainingErrKNN)],fontsize=10)
ax[0][1].legend([b[0],h2[0],h33[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=30) Missclassifaction is {:.3f}'.format(trainingErrKNN1)],fontsize=10)

#模型評估
print('Training error for LDA = {:.4f}'.format(trainErrLDA))
print('Training error for QDA = {:.4f}'.format(trainErrQDA))
print('Training error for KNN (k=15) = {:.4f}'.format(trainingErrKNN))
print('Training error for KNN (k=30) = {:.4f}'.format(trainingErrKNN1))
plt.savefig('statcomp_hw5_plot5.png')
# Out:
# Training error for LDA = 0.0321
# Training error for QDA = 0.0286
# Training error for KNN (k=15) = 0.0321
# Training error for KNN (k=30) = 0.0321

# %%
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis  import QuadraticDiscriminantAnalysis
from sklearn import neighbors
import numpy as np

# ... Generate simulated data X, y
X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([2, 3])]
            , Cov_list = [np.array([[1, 0], [0, 1]])
                          ,np.array([[1, 0], [0, 1]])] )

K =100

Lda_trainingError = np.zeros(K)
Lda_testingError = np.zeros(K)
Qda_trainingError = np.zeros(K)
Qda_testingError = np.zeros(K)
Knn_trainingError=np.zeros(K)
Knn_testingError=np.zeros(K)
Knn1_trainingError=np.zeros(K)
Knn1_testingError=np.zeros(K)

Lda = LinearDiscriminantAnalysis(tol = 1e-6)
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Knn = neighbors.KNeighborsClassifier(15, weights = 'uniform')    
Knn1 = neighbors.KNeighborsClassifier(30, weights = 'uniform')   

for i in range(K) :        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
        Lda.fit(X_train, y_train)
        Lda_trainingError[i] = 1-Lda.score(X_train,y_train)
        Lda_testingError[i] =1-Lda.score(X_test,y_test) 
        # print('LDA training Error:{:.4f}'.format(Lda_trainingError[i])) 
        # print('LDA testing Error:{:.4f}'.format(Lda_testingError[i]))   
        Qda.fit(X_train, y_train)
        Qda_trainingError[i] = 1-Qda.score(X_train,y_train)
        Qda_testingError[i] =1-Qda.score(X_test,y_test) 
        Knn.fit(X_train, y_train)
        Knn_trainingError[i] = 1-Knn.score(X_train,y_train)
        Knn_testingError[i] =1-Knn.score(X_test,y_test) 
        Knn1.fit(X_train, y_train)
        Knn1_trainingError[i] = 1-Knn1.score(X_train,y_train)
        Knn1_testingError[i] =1-Knn1.score(X_test,y_test)
print('LDA mean testing Error:{:.4f}'.format(Lda_testingError.mean()))        
print('LDA mean training Error:{:.4f}'.format(Lda_trainingError.mean()))
print('QDA mean testing Error:{:.4f}'.format(Qda_testingError.mean()))        
print('QDA mean training Error:{:.4f}'.format(Qda_trainingError.mean()))
print('Knn(n=15) mean testing Error:{:.4f}'.format(Knn_testingError.mean()))        
print('Knn(n=15) mean training Error:{:.4f}'.format(Knn_trainingError.mean()))
print('Knn(n=30) mean testing Error:{:.4f}'.format(Knn1_testingError.mean()))        
print('Knn(n=30) mean training Error:{:.4f}'.format(Knn1_trainingError.mean()))
# Out:
# LDA mean testing Error:0.0393
# LDA mean training Error:0.0354
# QDA mean testing Error:0.0381
# QDA mean training Error:0.0342
# Knn(n=15) mean testing Error:0.0448
# Knn(n=15) mean training Error:0.0374
# Knn(n=30) mean testing Error:0.0388
# Knn(n=30) mean training Error:0.0345

# %% [markdown]
# 2.$\mu$差異小

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([1, 1])]
            , Cov_list = [np.array([[0.5, 0], [0, 0.5]])
                          ,np.array([[0.5, 0], [0, 0.5]])] )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
D_train = np.hstack((X_train, y_train.reshape(-1, 1)))
D_test = np.hstack((X_test, y_test.reshape(-1, 1)))

D = D_train
X = D[:, 0:2]
y = D[:,2]

fig,ax=plt.subplots(1,2,figsize=(14,6),squeeze=False)
fig.suptitle('Different Models to Classify training dataset for two groups',fontsize = 14)
group_colors = ['blue' if i == 0 else 'red' for i in y]
ax[0][0].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' ) 
ax[0][1].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' )

#draw LDA
Lda=LinearDiscriminantAnalysis()
Lda.fit(X,y)
trainErrLDA=1-Lda.score(X,y)
x_min,x_max=plt.xlim()
y_min,y_max=plt.ylim()
x_=np.linspace(x_min,x_max,len(D[:, 0:1]))
y_=np.linspace(y_min,y_max,len(D[:, 1:2]))
xx,yy=np.meshgrid(x_,y_)
Z0=Lda.predict_proba(np.c_[xx.ravel(),yy.ravel()])#算出後驗機率
Z0=Z0[:,1].reshape(xx.shape)

# contoursLDA=ax[0][0].contour(xx,yy,Z0,[0.5],colors='g')
# contoursLDA1=ax[0][1].contour(xx,yy,Z0,[0.5],colors='g')
C1, C2 = X[y==0,:], X[y==1,:]
n = D[:,0].size
n1, n2 = C1[:,0].size, C2[:,0].size
pi1, pi2 = n1/n, n2/n
mu1, mu2 = np.mean(C1, axis = 0), np.mean(C2, axis = 0)
Sigma = (np.cov(C1.T) + np.cov(C2.T))/2
#draw classification line of LDA
K = np.log(pi1/pi2) - 0.5 * (mu1 + mu2)  @ LA.inv(Sigma) @ (mu1 - mu2).T
L = LA.inv(Sigma) @ (mu1 - mu2).T
f = lambda x : -L[0]/L[1] * x - K/L[1]
x = np.linspace(x_min,x_max, 10)
b=ax[0][0].plot(x, f(x) ,c = 'green' ,linestyle =':')
b=ax[0][1].plot(x, f(x) ,c = 'green' ,linestyle =':')
ax[0][0].set_ylim(-2,2.8)
ax[0][1].set_ylim(-2,2.8)

#draw QDA
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Qda.fit(X, y)
trainErrQDA=1-Qda.score(X,y)
Z2 = Qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z2 = Z2[:, 1].reshape(xx.shape)
contoursQDA= ax[0][0].contour(xx, yy, Z2, [0.5],colors = 'green' )
contoursQDA1= ax[0][1].contour(xx, yy, Z2, [0.5],colors = 'green' )

#draw KNN
K = [15,30]
Knn = neighbors.KNeighborsClassifier(K[0], weights = 'uniform')
Knn1 = neighbors.KNeighborsClassifier(K[1], weights = 'uniform')
Knn.fit(X, y)
Knn1.fit(X, y)
trainingErrKNN = 1 - Knn.score(X, y) 
trainingErrKNN1 = 1 - Knn1.score(X, y)

z1 = Knn.predict(np.c_[xx.ravel(), yy.ravel()])
z10 = Knn1.predict(np.c_[xx.ravel(), yy.ravel()])
Z1 = z1.reshape(xx.shape)
Z10 = z10.reshape(xx.shape)
cmap_light =colors.ListedColormap(['purple', 'pink'])
contoursKNN=ax[0][0].contourf(xx, yy, Z1, cmap = cmap_light, alpha = 0.3)
contoursKNN1=ax[0][1].contourf(xx, yy, Z10, cmap = cmap_light, alpha = 0.3)

# h1,_=contoursLDA.legend_elements()
# h11,_=contoursLDA1.legend_elements()
h2,_=contoursQDA.legend_elements()
h3,_=contoursKNN.legend_elements()
h33,_=contoursKNN1.legend_elements()

ax[0][0].legend([b[0],h2[0],h3[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=15) Missclassifaction is {:.3f}'.format(trainingErrKNN)],fontsize=10)
ax[0][1].legend([b[0],h2[0],h33[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=30) Missclassifaction is {:.3f}'.format(trainingErrKNN1)],fontsize=10)

#模型評估
print('Training error for LDA = {:.4f}'.format(trainErrLDA))
print('Training error for QDA = {:.4f}'.format(trainErrQDA))
print('Training error for KNN (k=15) = {:.4f}'.format(trainingErrKNN))
print('Training error for KNN (k=30) = {:.4f}'.format(trainingErrKNN1))
plt.savefig('statcomp_hw5_plot6.png')
# Out:
# Training error for LDA = 0.1679
# Training error for QDA = 0.1714
# Training error for KNN (k=15) = 0.1786
# Training error for KNN (k=30) = 0.1786

# %%
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis  import QuadraticDiscriminantAnalysis
from sklearn import neighbors
import numpy as np

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([1, 1])]
            , Cov_list = [np.array([[0.5, 0], [0, 0.5]])
                          ,np.array([[0.5, 0], [0, 0.5]])] )

K =100

Lda_trainingError = np.zeros(K)
Lda_testingError = np.zeros(K)
Qda_trainingError = np.zeros(K)
Qda_testingError = np.zeros(K)
Knn_trainingError=np.zeros(K)
Knn_testingError=np.zeros(K)
Knn1_trainingError=np.zeros(K)
Knn1_testingError=np.zeros(K)

Lda = LinearDiscriminantAnalysis(tol = 1e-6)
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Knn = neighbors.KNeighborsClassifier(15, weights = 'uniform')    
Knn1 = neighbors.KNeighborsClassifier(30, weights = 'uniform')   

for i in range(K) :        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
        Lda.fit(X_train, y_train)
        Lda_trainingError[i] = 1-Lda.score(X_train,y_train)
        Lda_testingError[i] =1-Lda.score(X_test,y_test) 
        # print('LDA training Error:{:.4f}'.format(Lda_trainingError[i])) 
        # print('LDA testing Error:{:.4f}'.format(Lda_testingError[i]))   
        Qda.fit(X_train, y_train)
        Qda_trainingError[i] = 1-Qda.score(X_train,y_train)
        Qda_testingError[i] =1-Qda.score(X_test,y_test) 
        Knn.fit(X_train, y_train)
        Knn_trainingError[i] = 1-Knn.score(X_train,y_train)
        Knn_testingError[i] =1-Knn.score(X_test,y_test) 
        Knn1.fit(X_train, y_train)
        Knn1_trainingError[i] = 1-Knn1.score(X_train,y_train)
        Knn1_testingError[i] =1-Knn1.score(X_test,y_test)
print('LDA mean testing Error:{:.4f}'.format(Lda_testingError.mean()))        
print('LDA mean training Error:{:.4f}'.format(Lda_trainingError.mean()))
print('QDA mean testing Error:{:.4f}'.format(Qda_testingError.mean()))        
print('QDA mean training Error:{:.4f}'.format(Qda_trainingError.mean()))
print('Knn(n=15) mean testing Error:{:.4f}'.format(Knn_testingError.mean()))        
print('Knn(n=15) mean training Error:{:.4f}'.format(Knn_trainingError.mean()))
print('Knn(n=30) mean testing Error:{:.4f}'.format(Knn1_testingError.mean()))        
print('Knn(n=30) mean training Error:{:.4f}'.format(Knn1_trainingError.mean()))
# Out:
# LDA mean testing Error:0.1756
# LDA mean training Error:0.1739
# QDA mean testing Error:0.1753
# QDA mean training Error:0.1726
# Knn(n=15) mean testing Error:0.1938
# Knn(n=15) mean training Error:0.1735
# Knn(n=30) mean testing Error:0.1900
# Knn(n=30) mean training Error:0.1819

# %% [markdown]
# 3.相關係數差異大

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([1, 0]) , np.array([1, 0])]
            , Cov_list = [np.array([[4, -5], [-5, 4]])
                          ,np.array([[4, 5], [5, 4]])] )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
D_train = np.hstack((X_train, y_train.reshape(-1, 1)))
D_test = np.hstack((X_test, y_test.reshape(-1, 1)))

D = D_train
X = D[:, 0:2]
y = D[:,2]

fig,ax=plt.subplots(1,2,figsize=(14,6),squeeze=False)
fig.suptitle('Different Models to Classify training dataset for two groups',fontsize = 14)
group_colors = ['blue' if i == 0 else 'red' for i in y]
ax[0][0].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' ) 
ax[0][1].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' )

#draw LDA
Lda=LinearDiscriminantAnalysis()
Lda.fit(X,y)
trainErrLDA=1-Lda.score(X,y)
x_min,x_max=plt.xlim()
y_min,y_max=plt.ylim()
x_=np.linspace(x_min,x_max,len(D[:, 0:1]))
y_=np.linspace(y_min,y_max,len(D[:, 1:2]))
xx,yy=np.meshgrid(x_,y_)
Z0=Lda.predict_proba(np.c_[xx.ravel(),yy.ravel()])#算出後驗機率
Z0=Z0[:,1].reshape(xx.shape)

# contoursLDA=ax[0][0].contour(xx,yy,Z0,[0.5],colors='g')
# contoursLDA1=ax[0][1].contour(xx,yy,Z0,[0.5],colors='g')
C1, C2 = X[y==0,:], X[y==1,:]
n = D[:,0].size
n1, n2 = C1[:,0].size, C2[:,0].size
pi1, pi2 = n1/n, n2/n
mu1, mu2 = np.mean(C1, axis = 0), np.mean(C2, axis = 0)
Sigma = (np.cov(C1.T) + np.cov(C2.T))/2
#draw classification line of LDA
K = np.log(pi1/pi2) - 0.5 * (mu1 + mu2)  @ LA.inv(Sigma) @ (mu1 - mu2).T
L = LA.inv(Sigma) @ (mu1 - mu2).T
f = lambda x : -L[0]/L[1] * x - K/L[1]
x = np.linspace(x_min,x_max, 10)
b=ax[0][0].plot(x, f(x) ,c = 'green' ,linestyle =':')
b=ax[0][1].plot(x, f(x) ,c = 'green' ,linestyle =':')

#draw QDA
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Qda.fit(X, y)
trainErrQDA=1-Qda.score(X,y)
Z2 = Qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z2 = Z2[:, 1].reshape(xx.shape)
contoursQDA= ax[0][0].contour(xx, yy, Z2, [0.5],colors = 'green' )
contoursQDA1= ax[0][1].contour(xx, yy, Z2, [0.5],colors = 'green' )

#draw KNN
K = [15,30]
Knn = neighbors.KNeighborsClassifier(K[0], weights = 'uniform')
Knn1 = neighbors.KNeighborsClassifier(K[1], weights = 'uniform')
Knn.fit(X, y)
Knn1.fit(X, y)
trainingErrKNN = 1 - Knn.score(X, y) 
trainingErrKNN1 = 1 - Knn1.score(X, y)

z1 = Knn.predict(np.c_[xx.ravel(), yy.ravel()])
z10 = Knn1.predict(np.c_[xx.ravel(), yy.ravel()])
Z1 = z1.reshape(xx.shape)
Z10 = z10.reshape(xx.shape)
cmap_light =colors.ListedColormap(['purple', 'pink'])
contoursKNN=ax[0][0].contourf(xx, yy, Z1, cmap = cmap_light, alpha = 0.3)
contoursKNN1=ax[0][1].contourf(xx, yy, Z10, cmap = cmap_light, alpha = 0.3)

# h1,_=contoursLDA.legend_elements()
# h11,_=contoursLDA1.legend_elements()
h2,_=contoursQDA.legend_elements()
h3,_=contoursKNN.legend_elements()
h33,_=contoursKNN1.legend_elements()

ax[0][0].legend([b[0],h2[0],h3[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=15) Missclassifaction is {:.3f}'.format(trainingErrKNN)],fontsize=10)
ax[0][1].legend([b[0],h2[0],h33[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=30) Missclassifaction is {:.3f}'.format(trainingErrKNN1)],fontsize=10)

#模型評估
print('Training error for LDA = {:.4f}'.format(trainErrLDA))
print('Training error for QDA = {:.4f}'.format(trainErrQDA))
print('Training error for KNN (k=15) = {:.4f}'.format(trainingErrKNN))
print('Training error for KNN (k=30) = {:.4f}'.format(trainingErrKNN1))

K =100

Lda_trainingError = np.zeros(K)
Lda_testingError = np.zeros(K)
Qda_trainingError = np.zeros(K)
Qda_testingError = np.zeros(K)
Knn_trainingError=np.zeros(K)
Knn_testingError=np.zeros(K)
Knn1_trainingError=np.zeros(K)
Knn1_testingError=np.zeros(K)

Lda = LinearDiscriminantAnalysis(tol = 1e-6)
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Knn = neighbors.KNeighborsClassifier(15, weights = 'uniform')    
Knn1 = neighbors.KNeighborsClassifier(30, weights = 'uniform')   

for i in range(K) :        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
        Lda.fit(X_train, y_train)
        Lda_trainingError[i] = 1-Lda.score(X_train,y_train)
        Lda_testingError[i] =1-Lda.score(X_test,y_test) 
        # print('LDA training Error:{:.4f}'.format(Lda_trainingError[i])) 
        # print('LDA testing Error:{:.4f}'.format(Lda_testingError[i]))   
        Qda.fit(X_train, y_train)
        Qda_trainingError[i] = 1-Qda.score(X_train,y_train)
        Qda_testingError[i] =1-Qda.score(X_test,y_test) 
        Knn.fit(X_train, y_train)
        Knn_trainingError[i] = 1-Knn.score(X_train,y_train)
        Knn_testingError[i] =1-Knn.score(X_test,y_test) 
        Knn1.fit(X_train, y_train)
        Knn1_trainingError[i] = 1-Knn1.score(X_train,y_train)
        Knn1_testingError[i] =1-Knn1.score(X_test,y_test)
print('LDA mean testing Error:{:.4f}'.format(Lda_testingError.mean()))        
print('LDA mean training Error:{:.4f}'.format(Lda_trainingError.mean()))
print('QDA mean testing Error:{:.4f}'.format(Qda_testingError.mean()))        
print('QDA mean training Error:{:.4f}'.format(Qda_trainingError.mean()))
print('Knn(n=15) mean testing Error:{:.4f}'.format(Knn_testingError.mean()))        
print('Knn(n=15) mean training Error:{:.4f}'.format(Knn_trainingError.mean()))
print('Knn(n=30) mean testing Error:{:.4f}'.format(Knn1_testingError.mean()))        
print('Knn(n=30) mean training Error:{:.4f}'.format(Knn1_trainingError.mean()))

plt.savefig('statcomp_hw5_plot7.png')
# Out:
# C:\Users\yangs\AppData\Local\Temp\ipykernel_17736\795068418.py:10: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   mvn = rng.multivariate_normal(mean=mu_list[i], cov=Cov_list[i], size=n)
# Training error for LDA = 0.4321
# Training error for QDA = 0.1607
# Training error for KNN (k=15) = 0.1643
# Training error for KNN (k=30) = 0.1607
# LDA mean testing Error:0.4658
# LDA mean training Error:0.4196
# QDA mean testing Error:0.1824
# QDA mean training Error:0.1658
# Knn(n=15) mean testing Error:0.1952
# Knn(n=15) mean training Error:0.1590
# Knn(n=30) mean testing Error:0.1954
# Knn(n=30) mean training Error:0.1634

# %% [markdown]
# 4.相關性相似

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([2, 0])]
            , Cov_list = [np.array([[1, 0.8], [0.8, 1]])
                          ,np.array([[1, 0.8], [0.8, 1]])] )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
D_train = np.hstack((X_train, y_train.reshape(-1, 1)))
D_test = np.hstack((X_test, y_test.reshape(-1, 1)))

D = D_train
X = D[:, 0:2]
y = D[:,2]

fig,ax=plt.subplots(1,2,figsize=(14,6),squeeze=False)
fig.suptitle('Different Models to Classify training dataset for two groups',fontsize = 14)
group_colors = ['blue' if i == 0 else 'red' for i in y]
ax[0][0].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' ) 
ax[0][1].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' )
ax[0][0].set_ylim(-4,6)
ax[0][1].set_ylim(-4,6)

#draw LDA
Lda=LinearDiscriminantAnalysis()
Lda.fit(X,y)
trainErrLDA=1-Lda.score(X,y)
x_min,x_max=-3,6
y_min,y_max=-4,6
x_=np.linspace(x_min,x_max,len(D[:, 0:1]))
y_=np.linspace(y_min,y_max,len(D[:, 1:2]))
xx,yy=np.meshgrid(x_,y_)
Z0=Lda.predict_proba(np.c_[xx.ravel(),yy.ravel()])#算出後驗機率
Z0=Z0[:,1].reshape(xx.shape)

# contoursLDA=ax[0][0].contour(xx,yy,Z0,[0.5],colors='g')
# contoursLDA1=ax[0][1].contour(xx,yy,Z0,[0.5],colors='g')
C1, C2 = X[y==0,:], X[y==1,:]
n = D[:,0].size
n1, n2 = C1[:,0].size, C2[:,0].size
pi1, pi2 = n1/n, n2/n
mu1, mu2 = np.mean(C1, axis = 0), np.mean(C2, axis = 0)
Sigma = (np.cov(C1.T) + np.cov(C2.T))/2
#draw classification line of LDA
K = np.log(pi1/pi2) - 0.5 * (mu1 + mu2)  @ LA.inv(Sigma) @ (mu1 - mu2).T
L = LA.inv(Sigma) @ (mu1 - mu2).T
f = lambda x : -L[0]/L[1] * x - K/L[1]
x = np.linspace(x_min,x_max, 10)
b=ax[0][0].plot(x, f(x) ,c = 'green' ,linestyle =':')
b=ax[0][1].plot(x, f(x) ,c = 'green' ,linestyle =':')

#draw QDA
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Qda.fit(X, y)
trainErrQDA=1-Qda.score(X,y)
Z2 = Qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z2 = Z2[:, 1].reshape(xx.shape)
contoursQDA= ax[0][0].contour(xx, yy, Z2, [0.5],colors = 'green' )
contoursQDA1= ax[0][1].contour(xx, yy, Z2, [0.5],colors = 'green' )

#draw KNN
K = [15,30]
Knn = neighbors.KNeighborsClassifier(K[0], weights = 'uniform')
Knn1 = neighbors.KNeighborsClassifier(K[1], weights = 'uniform')
Knn.fit(X, y)
Knn1.fit(X, y)
trainingErrKNN = 1 - Knn.score(X, y) 
trainingErrKNN1 = 1 - Knn1.score(X, y)

z1 = Knn.predict(np.c_[xx.ravel(), yy.ravel()])
z10 = Knn1.predict(np.c_[xx.ravel(), yy.ravel()])
Z1 = z1.reshape(xx.shape)
Z10 = z10.reshape(xx.shape)
cmap_light =colors.ListedColormap(['purple', 'pink'])
contoursKNN=ax[0][0].contourf(xx, yy, Z1, cmap = cmap_light, alpha = 0.3)
contoursKNN1=ax[0][1].contourf(xx, yy, Z10, cmap = cmap_light, alpha = 0.3)

# h1,_=contoursLDA.legend_elements()
# h11,_=contoursLDA1.legend_elements()
h2,_=contoursQDA.legend_elements()
h3,_=contoursKNN.legend_elements()
h33,_=contoursKNN1.legend_elements()

ax[0][0].legend([b[0],h2[0],h3[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=15) Missclassifaction is {:.3f}'.format(trainingErrKNN)],fontsize=10)
ax[0][1].legend([b[0],h2[0],h33[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=30) Missclassifaction is {:.3f}'.format(trainingErrKNN1)],fontsize=10)

#模型評估
print('Training error for LDA = {:.4f}'.format(trainErrLDA))
print('Training error for QDA = {:.4f}'.format(trainErrQDA))
print('Training error for KNN (k=15) = {:.4f}'.format(trainingErrKNN))
print('Training error for KNN (k=30) = {:.4f}'.format(trainingErrKNN1))

K =100

Lda_trainingError = np.zeros(K)
Lda_testingError = np.zeros(K)
Qda_trainingError = np.zeros(K)
Qda_testingError = np.zeros(K)
Knn_trainingError=np.zeros(K)
Knn_testingError=np.zeros(K)
Knn1_trainingError=np.zeros(K)
Knn1_testingError=np.zeros(K)

Lda = LinearDiscriminantAnalysis(tol = 1e-6)
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Knn = neighbors.KNeighborsClassifier(15, weights = 'uniform')    
Knn1 = neighbors.KNeighborsClassifier(30, weights = 'uniform')   

for i in range(K) :        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
        Lda.fit(X_train, y_train)
        Lda_trainingError[i] = 1-Lda.score(X_train,y_train)
        Lda_testingError[i] =1-Lda.score(X_test,y_test) 
        # print('LDA training Error:{:.4f}'.format(Lda_trainingError[i])) 
        # print('LDA testing Error:{:.4f}'.format(Lda_testingError[i]))   
        Qda.fit(X_train, y_train)
        Qda_trainingError[i] = 1-Qda.score(X_train,y_train)
        Qda_testingError[i] =1-Qda.score(X_test,y_test) 
        Knn.fit(X_train, y_train)
        Knn_trainingError[i] = 1-Knn.score(X_train,y_train)
        Knn_testingError[i] =1-Knn.score(X_test,y_test) 
        Knn1.fit(X_train, y_train)
        Knn1_trainingError[i] = 1-Knn1.score(X_train,y_train)
        Knn1_testingError[i] =1-Knn1.score(X_test,y_test)
print('LDA mean testing Error:{:.4f}'.format(Lda_testingError.mean()))        
print('LDA mean training Error:{:.4f}'.format(Lda_trainingError.mean()))
print('QDA mean testing Error:{:.4f}'.format(Qda_testingError.mean()))        
print('QDA mean training Error:{:.4f}'.format(Qda_trainingError.mean()))
print('Knn(n=15) mean testing Error:{:.4f}'.format(Knn_testingError.mean()))        
print('Knn(n=15) mean training Error:{:.4f}'.format(Knn_trainingError.mean()))
print('Knn(n=30) mean testing Error:{:.4f}'.format(Knn1_testingError.mean()))        
print('Knn(n=30) mean training Error:{:.4f}'.format(Knn1_trainingError.mean()))

plt.savefig('statcomp_hw5_plot8.png')
# Out:
# Training error for LDA = 0.0321
# Training error for QDA = 0.0429
# Training error for KNN (k=15) = 0.0429
# Training error for KNN (k=30) = 0.0464
# LDA mean testing Error:0.0367
# LDA mean training Error:0.0353
# QDA mean testing Error:0.0427
# QDA mean training Error:0.0409
# Knn(n=15) mean testing Error:0.0506
# Knn(n=15) mean training Error:0.0472
# Knn(n=30) mean testing Error:0.0615
# Knn(n=30) mean training Error:0.0599

# %% [markdown]
# 5.散佈差異大

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([0, 0])]
            , Cov_list = [np.array([[1, 0], [0 , 1]])
                          ,np.array([[0.2, 0], [0, 0.2]])] )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
D_train = np.hstack((X_train, y_train.reshape(-1, 1)))
D_test = np.hstack((X_test, y_test.reshape(-1, 1)))

D = D_train
X = D[:, 0:2]
y = D[:,2]

fig,ax=plt.subplots(1,2,figsize=(14,6),squeeze=False)
fig.suptitle('Different Models to Classify training dataset for two groups',fontsize = 14)
group_colors = ['blue' if i == 0 else 'red' for i in y]
ax[0][0].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' ) 
ax[0][1].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' )
ax[0][0].set_ylim(-3,2.5)
ax[0][1].set_ylim(-3,2.5)

#draw LDA
Lda=LinearDiscriminantAnalysis()
Lda.fit(X,y)
trainErrLDA=1-Lda.score(X,y)
x_min,x_max=plt.xlim()
y_min,y_max=plt.ylim()
x_=np.linspace(x_min,x_max,len(D[:, 0:1]))
y_=np.linspace(y_min,y_max,len(D[:, 1:2]))
xx,yy=np.meshgrid(x_,y_)
Z0=Lda.predict_proba(np.c_[xx.ravel(),yy.ravel()])#算出後驗機率
Z0=Z0[:,1].reshape(xx.shape)

# contoursLDA=ax[0][0].contour(xx,yy,Z0,[0.5],colors='g')
# contoursLDA1=ax[0][1].contour(xx,yy,Z0,[0.5],colors='g')
C1, C2 = X[y==0,:], X[y==1,:]
n = D[:,0].size
n1, n2 = C1[:,0].size, C2[:,0].size
pi1, pi2 = n1/n, n2/n
mu1, mu2 = np.mean(C1, axis = 0), np.mean(C2, axis = 0)
Sigma = (np.cov(C1.T) + np.cov(C2.T))/2
#draw classification line of LDA
K = np.log(pi1/pi2) - 0.5 * (mu1 + mu2)  @ LA.inv(Sigma) @ (mu1 - mu2).T
L = LA.inv(Sigma) @ (mu1 - mu2).T
f = lambda x : -L[0]/L[1] * x - K/L[1]
x = np.linspace(x_min,x_max, 10)
b=ax[0][0].plot(x, f(x) ,c = 'green' ,linestyle =':')
b=ax[0][1].plot(x, f(x) ,c = 'green' ,linestyle =':')

#draw QDA
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Qda.fit(X, y)
trainErrQDA=1-Qda.score(X,y)
Z2 = Qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z2 = Z2[:, 1].reshape(xx.shape)
contoursQDA= ax[0][0].contour(xx, yy, Z2, [0.5],colors = 'green' )
contoursQDA1= ax[0][1].contour(xx, yy, Z2, [0.5],colors = 'green' )

#draw KNN
K = [15,30]
Knn = neighbors.KNeighborsClassifier(K[0], weights = 'uniform')
Knn1 = neighbors.KNeighborsClassifier(K[1], weights = 'uniform')
Knn.fit(X, y)
Knn1.fit(X, y)
trainingErrKNN = 1 - Knn.score(X, y) 
trainingErrKNN1 = 1 - Knn1.score(X, y)

z1 = Knn.predict(np.c_[xx.ravel(), yy.ravel()])
z10 = Knn1.predict(np.c_[xx.ravel(), yy.ravel()])
Z1 = z1.reshape(xx.shape)
Z10 = z10.reshape(xx.shape)
cmap_light =colors.ListedColormap(['purple', 'pink'])
contoursKNN=ax[0][0].contourf(xx, yy, Z1, cmap = cmap_light, alpha = 0.3)
contoursKNN1=ax[0][1].contourf(xx, yy, Z10, cmap = cmap_light, alpha = 0.3)

# h1,_=contoursLDA.legend_elements()
# h11,_=contoursLDA1.legend_elements()
h2,_=contoursQDA.legend_elements()
h3,_=contoursKNN.legend_elements()
h33,_=contoursKNN1.legend_elements()

ax[0][0].legend([b[0],h2[0],h3[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=15) Missclassifaction is {:.3f}'.format(trainingErrKNN)],fontsize=10)
ax[0][1].legend([b[0],h2[0],h33[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=30) Missclassifaction is {:.3f}'.format(trainingErrKNN1)],fontsize=10)

#模型評估
print('Training error for LDA = {:.4f}'.format(trainErrLDA))
print('Training error for QDA = {:.4f}'.format(trainErrQDA))
print('Training error for KNN (k=15) = {:.4f}'.format(trainingErrKNN))
print('Training error for KNN (k=30) = {:.4f}'.format(trainingErrKNN1))

K =100

Lda_trainingError = np.zeros(K)
Lda_testingError = np.zeros(K)
Qda_trainingError = np.zeros(K)
Qda_testingError = np.zeros(K)
Knn_trainingError=np.zeros(K)
Knn_testingError=np.zeros(K)
Knn1_trainingError=np.zeros(K)
Knn1_testingError=np.zeros(K)

Lda = LinearDiscriminantAnalysis(tol = 1e-6)
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Knn = neighbors.KNeighborsClassifier(15, weights = 'uniform')    
Knn1 = neighbors.KNeighborsClassifier(30, weights = 'uniform')   

for i in range(K) :        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
        Lda.fit(X_train, y_train)
        Lda_trainingError[i] = 1-Lda.score(X_train,y_train)
        Lda_testingError[i] =1-Lda.score(X_test,y_test) 
        # print('LDA training Error:{:.4f}'.format(Lda_trainingError[i])) 
        # print('LDA testing Error:{:.4f}'.format(Lda_testingError[i]))   
        Qda.fit(X_train, y_train)
        Qda_trainingError[i] = 1-Qda.score(X_train,y_train)
        Qda_testingError[i] =1-Qda.score(X_test,y_test) 
        Knn.fit(X_train, y_train)
        Knn_trainingError[i] = 1-Knn.score(X_train,y_train)
        Knn_testingError[i] =1-Knn.score(X_test,y_test) 
        Knn1.fit(X_train, y_train)
        Knn1_trainingError[i] = 1-Knn1.score(X_train,y_train)
        Knn1_testingError[i] =1-Knn1.score(X_test,y_test)
print('LDA mean testing Error:{:.4f}'.format(Lda_testingError.mean()))        
print('LDA mean training Error:{:.4f}'.format(Lda_trainingError.mean()))
print('QDA mean testing Error:{:.4f}'.format(Qda_testingError.mean()))        
print('QDA mean training Error:{:.4f}'.format(Qda_trainingError.mean()))
print('Knn(n=15) mean testing Error:{:.4f}'.format(Knn_testingError.mean()))        
print('Knn(n=15) mean training Error:{:.4f}'.format(Knn_trainingError.mean()))
print('Knn(n=30) mean testing Error:{:.4f}'.format(Knn1_testingError.mean()))        
print('Knn(n=30) mean training Error:{:.4f}'.format(Knn1_trainingError.mean()))

plt.savefig('statcomp_hw5_plot9.png')
# Out:
# Training error for LDA = 0.3964
# Training error for QDA = 0.2357
# Training error for KNN (k=15) = 0.2286
# Training error for KNN (k=30) = 0.2393
# LDA mean testing Error:0.5130
# LDA mean training Error:0.4440
# QDA mean testing Error:0.2349
# QDA mean training Error:0.2334
# Knn(n=15) mean testing Error:0.2681
# Knn(n=15) mean training Error:0.2393
# Knn(n=30) mean testing Error:0.2729
# Knn(n=30) mean training Error:0.2560

# %% [markdown]
# 6.散佈差異小

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

X,y= GenDataforN(seed = 123 , n_list =[200,200]
            , mu_list = [np.array([0, 0]) , np.array([0, 0])]
            , Cov_list = [np.array([[5, 0], [0, 5]])
                          ,np.array([[3, 0], [0, 3]])] )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
D_train = np.hstack((X_train, y_train.reshape(-1, 1)))
D_test = np.hstack((X_test, y_test.reshape(-1, 1)))

D = D_train
X = D[:, 0:2]
y = D[:,2]

fig,ax=plt.subplots(1,2,figsize=(14,6),squeeze=False)
fig.suptitle('Different Models to Classify training dataset for two groups',fontsize = 14)
group_colors = ['blue' if i == 0 else 'red' for i in y]
ax[0][0].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' ) 
ax[0][1].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' )

#draw LDA
Lda=LinearDiscriminantAnalysis()
Lda.fit(X,y)
trainErrLDA=1-Lda.score(X,y)
x_min,x_max=plt.xlim()
y_min,y_max=plt.ylim()
x_=np.linspace(x_min,x_max,len(D[:, 0:1]))
y_=np.linspace(y_min,y_max,len(D[:, 1:2]))
xx,yy=np.meshgrid(x_,y_)
Z0=Lda.predict_proba(np.c_[xx.ravel(),yy.ravel()])#算出後驗機率
Z0=Z0[:,1].reshape(xx.shape)

# contoursLDA=ax[0][0].contour(xx,yy,Z0,[0.5],colors='g')
# contoursLDA1=ax[0][1].contour(xx,yy,Z0,[0.5],colors='g')
C1, C2 = X[y==0,:], X[y==1,:]
n = D[:,0].size
n1, n2 = C1[:,0].size, C2[:,0].size
pi1, pi2 = n1/n, n2/n
mu1, mu2 = np.mean(C1, axis = 0), np.mean(C2, axis = 0)
Sigma = (np.cov(C1.T) + np.cov(C2.T))/2
#draw classification line of LDA
K = np.log(pi1/pi2) - 0.5 * (mu1 + mu2)  @ LA.inv(Sigma) @ (mu1 - mu2).T
L = LA.inv(Sigma) @ (mu1 - mu2).T
f = lambda x : -L[0]/L[1] * x - K/L[1]
x = np.linspace(x_min,x_max, 10)
b=ax[0][0].plot(x, f(x) ,c = 'green' ,linestyle =':')
b=ax[0][1].plot(x, f(x) ,c = 'green' ,linestyle =':')

#draw QDA
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Qda.fit(X, y)
trainErrQDA=1-Qda.score(X,y)
Z2 = Qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z2 = Z2[:, 1].reshape(xx.shape)
contoursQDA= ax[0][0].contour(xx, yy, Z2, [0.5],colors = 'green' )
contoursQDA1= ax[0][1].contour(xx, yy, Z2, [0.5],colors = 'green' )

#draw KNN
K = [15,30]
Knn = neighbors.KNeighborsClassifier(K[0], weights = 'uniform')
Knn1 = neighbors.KNeighborsClassifier(K[1], weights = 'uniform')
Knn.fit(X, y)
Knn1.fit(X, y)
trainingErrKNN = 1 - Knn.score(X, y) 
trainingErrKNN1 = 1 - Knn1.score(X, y)

z1 = Knn.predict(np.c_[xx.ravel(), yy.ravel()])
z10 = Knn1.predict(np.c_[xx.ravel(), yy.ravel()])
Z1 = z1.reshape(xx.shape)
Z10 = z10.reshape(xx.shape)
cmap_light =colors.ListedColormap(['purple', 'pink'])
contoursKNN=ax[0][0].contourf(xx, yy, Z1, cmap = cmap_light, alpha = 0.3)
contoursKNN1=ax[0][1].contourf(xx, yy, Z10, cmap = cmap_light, alpha = 0.3)

# h1,_=contoursLDA.legend_elements()
# h11,_=contoursLDA1.legend_elements()
h2,_=contoursQDA.legend_elements()
h3,_=contoursKNN.legend_elements()
h33,_=contoursKNN1.legend_elements()

ax[0][0].legend([b[0],h2[0],h3[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=15) Missclassifaction is {:.3f}'.format(trainingErrKNN)],fontsize=10)
ax[0][1].legend([b[0],h2[0],h33[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=30) Missclassifaction is {:.3f}'.format(trainingErrKNN1)],fontsize=10)

#模型評估
print('Training error for LDA = {:.4f}'.format(trainErrLDA))
print('Training error for QDA = {:.4f}'.format(trainErrQDA))
print('Training error for KNN (k=15) = {:.4f}'.format(trainingErrKNN))
print('Training error for KNN (k=30) = {:.4f}'.format(trainingErrKNN1))

K =100

Lda_trainingError = np.zeros(K)
Lda_testingError = np.zeros(K)
Qda_trainingError = np.zeros(K)
Qda_testingError = np.zeros(K)
Knn_trainingError=np.zeros(K)
Knn_testingError=np.zeros(K)
Knn1_trainingError=np.zeros(K)
Knn1_testingError=np.zeros(K)

Lda = LinearDiscriminantAnalysis(tol = 1e-6)
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Knn = neighbors.KNeighborsClassifier(15, weights = 'uniform')    
Knn1 = neighbors.KNeighborsClassifier(30, weights = 'uniform')   

for i in range(K) :        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
        Lda.fit(X_train, y_train)
        Lda_trainingError[i] = 1-Lda.score(X_train,y_train)
        Lda_testingError[i] =1-Lda.score(X_test,y_test) 
        # print('LDA training Error:{:.4f}'.format(Lda_trainingError[i])) 
        # print('LDA testing Error:{:.4f}'.format(Lda_testingError[i]))   
        Qda.fit(X_train, y_train)
        Qda_trainingError[i] = 1-Qda.score(X_train,y_train)
        Qda_testingError[i] =1-Qda.score(X_test,y_test) 
        Knn.fit(X_train, y_train)
        Knn_trainingError[i] = 1-Knn.score(X_train,y_train)
        Knn_testingError[i] =1-Knn.score(X_test,y_test) 
        Knn1.fit(X_train, y_train)
        Knn1_trainingError[i] = 1-Knn1.score(X_train,y_train)
        Knn1_testingError[i] =1-Knn1.score(X_test,y_test)
print('LDA mean testing Error:{:.4f}'.format(Lda_testingError.mean()))        
print('LDA mean training Error:{:.4f}'.format(Lda_trainingError.mean()))
print('QDA mean testing Error:{:.4f}'.format(Qda_testingError.mean()))        
print('QDA mean training Error:{:.4f}'.format(Qda_trainingError.mean()))
print('Knn(n=15) mean testing Error:{:.4f}'.format(Knn_testingError.mean()))        
print('Knn(n=15) mean training Error:{:.4f}'.format(Knn_trainingError.mean()))
print('Knn(n=30) mean testing Error:{:.4f}'.format(Knn1_testingError.mean()))        
print('Knn(n=30) mean training Error:{:.4f}'.format(Knn1_trainingError.mean()))

plt.savefig('statcomp_hw5_plot10.png')
# Out:
# Training error for LDA = 0.4393
# Training error for QDA = 0.3929
# Training error for KNN (k=15) = 0.3607
# Training error for KNN (k=30) = 0.4036
# LDA mean testing Error:0.5185
# LDA mean training Error:0.4551
# QDA mean testing Error:0.4156
# QDA mean training Error:0.3908
# Knn(n=15) mean testing Error:0.4708
# Knn(n=15) mean training Error:0.3785
# Knn(n=30) mean testing Error:0.4593
# Knn(n=30) mean training Error:0.3985

# %% [markdown]
# ### 3群資料判別

# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
from sklearn import neighbors
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

X,y= GenDataforN(seed = 123 , n_list =[200,200,200]
            , mu_list = [np.array([0, 0]) , np.array([2, 3]) , np.array([-2, 3]) ]
            , Cov_list = [np.array([[1, 0], [0, 1]])
                          ,np.array([[1, 0], [0, 1]])
                          ,np.array([[1, 0], [0, 1]])
                          ] )

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
D_train = np.hstack((X_train, y_train.reshape(-1, 1)))
D_test = np.hstack((X_test, y_test.reshape(-1, 1)))

D = D_train
X = D[:, 0:2]
y = D[:,2]

fig,ax=plt.subplots(1,2,figsize=(14,6),squeeze=False)
fig.suptitle('Different Models to Classify training dataset for three groups',fontsize = 14)
group_colors = ['blue' if i == 0 else 'red' if i == 1 else 'yellow' for i in y]
ax[0][0].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' ) 
ax[0][1].scatter(D[:, 0], D[:, 1], c = group_colors, s = 30, alpha = 0.7, marker = 'o' )
x_min, x_max = plt.xlim() 
y_min, y_max = plt.ylim()
x_=np.linspace(x_min,x_max,len(D[:, 0:1]))
y_=np.linspace(y_min,y_max,len(D[:, 1:2]))
xx,yy=np.meshgrid(x_,y_)

#lda model
Lda=LinearDiscriminantAnalysis()
Lda.fit(X,y)
intrcp=Lda.intercept_
coeffs=Lda.coef_
trainErrLDA=1-Lda.score(X,y)
ZLDA=Lda.predict_proba(np.c_[xx.ravel(),yy.ravel()])

#qda model
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Qda.fit(X, y)
trainErrQDA=1-Qda.score(X,y)
ZQDA = Qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])

#knn model 
K = [15,30]
Knn = neighbors.KNeighborsClassifier(K[0], weights = 'uniform')
Knn1 = neighbors.KNeighborsClassifier(K[1], weights = 'uniform')
Knn.fit(X, y) ; Knn1.fit(X, y)
trainingErrKNN = 1 - Knn.score(X, y) ; trainingErrKNN1 = 1 - Knn1.score(X, y)
ZKNN = Knn.predict(np.c_[xx.ravel(), yy.ravel()])
ZKNN1 = Knn1.predict(np.c_[xx.ravel(), yy.ravel()])

#contour plot
for i in range(ZLDA[:, 0].reshape(xx.shape).ndim+1) :
    for j in range(2):
        contoursLDA = ax[0][j].contour(xx, yy, ZLDA[:, i].reshape(xx.shape), [0.5],colors = 'g' ,linestyles = '--')
        contoursQDA = ax[0][j].contour(xx, yy, ZQDA[:, i].reshape(xx.shape), [0.5],colors = 'g')
cmap_light =colors.ListedColormap(['purple', 'pink' , 'orange'])
contoursKNN=ax[0][0].contourf(xx, yy, ZKNN.reshape(xx.shape), cmap = cmap_light, alpha = 0.3)
contoursKNN1=ax[0][1].contourf(xx, yy, ZKNN1.reshape(xx.shape), cmap = cmap_light, alpha = 0.3)

#legend
h1,_=contoursLDA.legend_elements()
h2,_=contoursQDA.legend_elements()
h3,_=contoursKNN.legend_elements()
h33,_=contoursKNN1.legend_elements()
ax[0][0].legend([h1[0],h2[0],h3[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=15) Missclassifaction is {:.3f}'.format(trainingErrKNN)],fontsize=10)
ax[0][1].legend([h1[0],h2[0],h33[0]],['LDA Missclassifaction is {:.3f}'.format(trainErrLDA),'QDA Missclassifaction is {:.3f}'.format(trainErrQDA),'KNN (k=30) Missclassifaction is {:.3f}'.format(trainingErrKNN1)],fontsize=10)

#4 model error
print('LDA Missclassifaction is {:.4f}'.format(trainErrLDA))
print('QDA Missclassifaction is {:.4f}'.format(trainErrQDA))
print('KNN Missclassifaction is {:.4f}'.format(trainingErrKNN))
print('KNN1 Missclassifaction is {:.4f}'.format(trainingErrKNN1))

K =100

Lda_trainingError = np.zeros(K)
Lda_testingError = np.zeros(K)
Qda_trainingError = np.zeros(K)
Qda_testingError = np.zeros(K)
Knn_trainingError=np.zeros(K)
Knn_testingError=np.zeros(K)
Knn1_trainingError=np.zeros(K)
Knn1_testingError=np.zeros(K)

Lda = LinearDiscriminantAnalysis(tol = 1e-6)
Qda = QuadraticDiscriminantAnalysis(tol = 1e-6, store_covariance = True)
Knn = neighbors.KNeighborsClassifier(15, weights = 'uniform')    
Knn1 = neighbors.KNeighborsClassifier(30, weights = 'uniform')   

for i in range(K) :        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
        Lda.fit(X_train, y_train)
        Lda_trainingError[i] = 1-Lda.score(X_train,y_train)
        Lda_testingError[i] =1-Lda.score(X_test,y_test) 
        # print('LDA training Error:{:.4f}'.format(Lda_trainingError[i])) 
        # print('LDA testing Error:{:.4f}'.format(Lda_testingError[i]))   
        Qda.fit(X_train, y_train)
        Qda_trainingError[i] = 1-Qda.score(X_train,y_train)
        Qda_testingError[i] =1-Qda.score(X_test,y_test) 
        Knn.fit(X_train, y_train)
        Knn_trainingError[i] = 1-Knn.score(X_train,y_train)
        Knn_testingError[i] =1-Knn.score(X_test,y_test) 
        Knn1.fit(X_train, y_train)
        Knn1_trainingError[i] = 1-Knn1.score(X_train,y_train)
        Knn1_testingError[i] =1-Knn1.score(X_test,y_test)
print('LDA mean testing Error:{:.4f}'.format(Lda_testingError.mean()))        
print('LDA mean training Error:{:.4f}'.format(Lda_trainingError.mean()))
print('QDA mean testing Error:{:.4f}'.format(Qda_testingError.mean()))        
print('QDA mean training Error:{:.4f}'.format(Qda_trainingError.mean()))
print('Knn(n=15) mean testing Error:{:.4f}'.format(Knn_testingError.mean()))        
print('Knn(n=15) mean training Error:{:.4f}'.format(Knn_trainingError.mean()))
print('Knn(n=30) mean testing Error:{:.4f}'.format(Knn1_testingError.mean()))        
print('Knn(n=30) mean training Error:{:.4f}'.format(Knn1_trainingError.mean()))

plt.savefig('statcomp_hw5_plot11.png')
# Out:
# LDA Missclassifaction is 0.0524
# QDA Missclassifaction is 0.0524
# KNN Missclassifaction is 0.0524
# KNN1 Missclassifaction is 0.0500
# LDA mean testing Error:0.0502
# LDA mean training Error:0.0519
# QDA mean testing Error:0.0499
# QDA mean training Error:0.0492
# Knn(n=15) mean testing Error:0.0556
# Knn(n=15) mean training Error:0.0514
# Knn(n=30) mean testing Error:0.0482
# Knn(n=30) mean training Error:0.0483
